# %%
import pyedflib
import numpy as np
import xmltodict
import json
import mne
import matplotlib
import math
import pathlib
from mne_extras import write_mne_edf
from openpyxl import Workbook
from openpyxl.styles import PatternFill, Border, Side

# %%
matplotlib.use('Qt5Agg')

# %%
def analyze(this_epochs):
    # , xscale = 'log', Pz.., Fpz. 
#     this_epochs[0:22].filter(l_freq = 0.5, h_freq = 30).pick_channels(['Pz..']).plot()
#     this_epochs[0:22].filter(l_freq = 0.5, h_freq = 30).pick_channels(['Pz..']).plot_psd(average = True, color = 'blue', fmin = 1, fmax = 30, dB = True, estimate = 'amplitude')
    normal = this_epochs.copy().pick_channels(['Fp1.'])
    ear_ref = this_epochs.copy().set_eeg_reference(['T7..']).pick_channels(['Fp1.'])
    head_ref = this_epochs.copy().set_eeg_reference(['Fp2.']).pick_channels(['Fp1.'])
#     ear_ref.plot()
#     head_ref.plot()

    print(this_epochs.get.data())
    
    power = []
    delta = []
    theta = []
    alpha = []
    beta = []
    gamma = []

#     for epochs in this_epochs:  

#         variances.append(np.var(out_signal))
    epochs = head_ref
    psds_total, frqs_total = mne.time_frequency.psd_multitaper(epochs, fmin=0.5, fmax=44.5, tmin=None, tmax=None)
    total_sum_pds = np.sum(psds_total)

    psds_power, frqs_power = mne.time_frequency.psd_multitaper(epochs, fmin=45, fmax=55, tmin=None, tmax=None)
    power_sum_pds = np.sum(psds_power)
    power_ratio = (power_sum_pds) / (total_sum_pds)
    power.append(power_ratio)

    psds_delta, frqs_delta = mne.time_frequency.psd_multitaper(epochs, fmin=1.5, fmax=4.5, tmin=None, tmax=None)
    delta_sum_pds = np.sum(psds_delta)
    delta_ratio = (delta_sum_pds) / (total_sum_pds)
    delta.append(delta_ratio)

    psds_theta, frqs_theta = mne.time_frequency.psd_multitaper(epochs, fmin=4.5, fmax=7.5, tmin=None, tmax=None)
    theta_sum_pds = np.sum(psds_theta)
    theta_ratio = (theta_sum_pds) / (total_sum_pds)
    theta.append(theta_ratio)

    psds_alpha, frqs_alpha = mne.time_frequency.psd_multitaper(epochs, fmin=7.5, fmax=12.5, tmin=None, tmax=None)
    alpha_sum_pds = np.sum(psds_alpha)
    alpha_ratio = (alpha_sum_pds) / (total_sum_pds)
    alpha.append(alpha_ratio)

    psds_beta, frqs_beta = mne.time_frequency.psd_multitaper(epochs, fmin=14.5, fmax=29.5, tmin=None, tmax=None)
    beta_sum_pds = np.sum(psds_beta)
    beta_ratio = (beta_sum_pds) / (total_sum_pds)
    beta.append(beta_ratio)

    psds_gamma, frqs_gamma = mne.time_frequency.psd_multitaper(epochs, fmin=29.5, fmax=45.5, tmin=None, tmax=None)
    gamma_sum_pds = np.sum(psds_gamma)
    gamma_ratio = (gamma_sum_pds) / (total_sum_pds)
    gamma.append(gamma_ratio)
    
    df = this_epochs.to_data_frame()
    var = np.var(df)
    print((var))
    print(len(var))
    print(sum(df.var()[2:]))
    var_avg = sum(df.var()[2:]) / 64
    result = [power, delta, theta, alpha, beta, gamma, [var_avg]]
    print(result[6])
    return result

# %%
exp = []
expRaw = []
event_dict = {'divide':1}
n = 109-107
epochs = []
variances = []

# headers = [{'label':'ch1', 
#             'dimension': 'uV',
#             'sample_rate': 160,
#             'physical_max': 5000,
#             "physical_min": -5000,
#             'digital_max': 5000,
#             'digital_min': -5000,
#             'transducer': 'None',
#             'prefilter': 'None'},
#             {'label':'ch2', 
#             'dimension': 'uV',
#             'sample_rate': 160,
#             'physical_max': 5000,
#             "physical_min": -5000,
#             'digital_max': 5000,
#             'digital_min': -5000,
#             'transducer': 'None',
#             'prefilter': 'None'},
#           {'label':'ch3', 
#             'dimension': 'uV',
#             'sample_rate': 160,
#             'physical_max': 5000,
#             "physical_min": -5000,
#             'digital_max': 5000,
#             'digital_min': -5000,
#             'transducer': 'None',
#             'prefilter': 'None'},
#           {'label':'ch4', 
#             'dimension': 'uV',
#             'sample_rate': 160,
#             'physical_max': 5000,
#             "physical_min": -5000,
#             'digital_max': 5000,
#             'digital_min': -5000,
#             'transducer': 'None',
#             'prefilter': 'None'},
#           {'label':'ch5', 
#             'dimension': 'uV',
#             'sample_rate': 160,
#             'physical_max': 5000,
#             "physical_min": -5000,
#             'digital_max': 5000,
#             'digital_min': -5000,
#             'transducer': 'None',
#             'prefilter': 'None'},
#           {'label':'ch6', 
#             'dimension': 'uV',
#             'sample_rate': 160,
#             'physical_max': 5000,
#             "physical_min": -5000,
#             'digital_max': 5000,
#             'digital_min': -5000,
#             'transducer': 'None',
#             'prefilter': 'None'}]

wb = Workbook()
ws = wb.active
ws.title = 'EEG Compositional Analysis'
ws.sheet_properties.tabColor = "1072BA"

# ws.cell(row=1, column=1).value = 'normal.power'
# ws.cell(row=1, column=2).value = 'normal.delta'
# ws.cell(row=1, column=3).value = 'normal.theta'
# ws.cell(row=1, column=4).value = 'normal.alpha'
# ws.cell(row=1, column=5).value = 'normal.beta'
# ws.cell(row=1, column=6).value = 'normal.gamma'
# ws.cell(row=1, column=7).value = 'normal.var'

# ws.cell(row=1, column=7).value = 'ear.power'
# ws.cell(row=1, column=8).value = 'ear.delta'
# ws.cell(row=1, column=9).value = 'ear.theta'
# ws.cell(row=1, column=10).value = 'ear.alpha'
# ws.cell(row=1, column=11).value = 'ear.beta'
# ws.cell(row=1, column=12).value = 'ear.gamma'

ws.cell(row=1, column=1).value = 'forehead.power'
ws.cell(row=1, column=2).value = 'forehead.delta'
ws.cell(row=1, column=3).value = 'forehead.theta'
ws.cell(row=1, column=4).value = 'forehead.alpha'
ws.cell(row=1, column=5).value = 'forehead.beta'
ws.cell(row=1, column=6).value = 'forehead.gamma'
ws.cell(row=1, column=7).value = 'forehead.var'

for i in range(1,8):
    ws.cell(row=1, column=i).fill = PatternFill(fill_type='solid',
                start_color='00CCFFFF',
                end_color='FF000000')
ws.sheet_format.baseColWidth=15
    
for i in range(0,n):
    print('this is: ' + str(i))
    exp.append(mne.datasets.eegbci.load_data(i+1, 2, path=None, force_update=False, update_path=None, base_url='https://physionet.org/files/eegmmidb/1.0.0/', verbose=None)[0])
    expRaw.append(mne.io.read_raw_edf(exp[i]))
    
    
    
    events_all = mne.events_from_annotations(expRaw[i])
    new_events = mne.make_fixed_length_events(expRaw[i], duration=2.)
    events = events_all[0]
    event_id = events_all[1]
    # two on top of forehead and one on top of left ear
    
    
#     expRaw[i].plot(n_channels = 1, bgcolor = 'white', color = 'blue', show_scrollbars = False)
    
    
    this_epochs = mne.Epochs(expRaw[i], new_events, reject_by_annotation=False, preload=True)
    epochs.append(this_epochs)
    
#     df = this_epochs.to_data_frame()

#     #original data for forehead and ear eeg (default refrence at Cz)
#     out_raw_one = df['Fp1.']
#     out_raw_two = df['Fp2.']
#     out_raw_three = df['T7..']
    
#     #forehead eeg with ear as refrence
#     out_raw_four = df['Fp1.']  - df['T7..']
#     out_raw_five = df['Fp2.']  - df['T7..']
    
#     #one forehead eeg with the other as refrence
#     out_raw_six = df['Fp1.']  - df['Fp2.']

#     out_signal = [np.array(out_raw_one), np.array(out_raw_two), np.array(out_raw_three), np.array(out_raw_four), np.array(out_raw_five), np.array(out_raw_six)]
    
#     with open('./mne_data_analysis_output/forthCH_Fp1_Fp2'+str(i)+'.edf', 'w') as output:
#         flag = pyedflib.highlevel.write_edf(output.name, out_signal, headers, header=None, digital=False, file_type=-1, block_size=1)
#         #print(flag)
        
    result = analyze(this_epochs)
    print(len(result))
    print(len(result[0]))
    for x in range(0,len(result)):
        ws.cell(row=i+2, column=x+1).value = result[x][0]
#     for x in range(0,len(result)):
#         ws.cell(row=i+2, column=len(result)+x+1).value = result[x][0]
#     for x in range(0,len(result)):
#         ws.cell(row=i+2, column=2*len(result)+x+1).value = result[x][0]
    
wb.save('mne_data_analysis_fp2.xlsx')
# Out:
# this is: 0
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S001\S001R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1950.362612
# Fc3.      2176.397322
# Fc1.      2389.074539
#              ...
# Po8.      6055.040172
# O1..      6294.322209
# Oz..      5256.596134
# O2..      5922.335127
# Iz..      3794.701128
# Length: 66, dtype: float64
# 66
# 171585.30433031285
# [2681.0203801611383]
# 7
# 1
# this is: 1
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S002\S002R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       618.455831
# Fc3.       703.677493
# Fc1.       841.470372
#              ...
# Po8.      1377.140932
# O1..      1906.884185
# Oz..      1171.801672
# O2..      2074.676370
# Iz..      1167.760570
# Length: 66, dtype: float64
# 66
# 60551.88500762158
# [946.1232032440872]
# 7
# 1
# this is: 2
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S003\S003R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      2594.014625
# Fc3.      2450.661768
# Fc1.      2161.496882
#              ...
# Po8.      3202.192362
# O1..      5220.052334
# Oz..      3981.170451
# O2..      4061.308629
# Iz..      3244.149696
# Length: 66, dtype: float64
# 66
# 195472.7034549343
# [3054.2609914833483]
# 7
# 1
# this is: 3
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S004\S004R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       471.938109
# Fc3.       986.333744
# Fc1.       578.408033
#              ...
# Po8.       902.702583
# O1..       919.156516
# Oz..       788.960771
# O2..       816.728611
# Iz..       476.481585
# Length: 66, dtype: float64
# 66
# 41343.92200189993
# [645.9987812796865]
# 7
# 1
# this is: 4
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S005\S005R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      4413.592202
# Fc3.       632.035217
# Fc1.      1921.660445
#              ...
# Po8.      2444.041176
# O1..       878.839211
# Oz..      1319.117027
# O2..      1649.556888
# Iz..       474.308091
# Length: 66, dtype: float64
# 66
# 111224.67116223738
# [1737.8854869099591]
# 7
# 1
# this is: 5
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S006\S006R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       464.065086
# Fc3.       353.347225
# Fc1.       353.866275
#              ...
# Po8.       264.498523
# O1..       279.172811
# Oz..       301.331463
# O2..       291.006788
# Iz..       240.659905
# Length: 66, dtype: float64
# 66
# 21834.73379832998
# [341.16771559890594]
# 7
# 1
# this is: 6
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S007\S007R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1540.127573
# Fc3.      1719.713734
# Fc1.      1789.318613
#              ...
# Po8.      2543.652311
# O1..      3582.415149
# Oz..      3185.943520
# O2..      2970.888322
# Iz..      1432.302740
# Length: 66, dtype: float64
# 66
# 123652.18724222742
# [1932.0654256598034]
# 7
# 1
# this is: 7
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S008\S008R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1116.408287
# Fc3.      1241.767040
# Fc1.      1197.530133
#              ...
# Po8.       751.478319
# O1..       854.259613
# Oz..       746.649726
# O2..       688.242845
# Iz..       602.188526
# Length: 66, dtype: float64
# 66
# 82786.29044369608
# [1293.5357881827513]
# 7
# 1
# this is: 8
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S009\S009R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      3522.364390
# Fc3.      2386.254199
# Fc1.      2298.882982
#              ...
# Po8.      1792.206829
# O1..      2021.381947
# Oz..      1746.730913
# O2..      1679.812362
# Iz..      2217.509555
# Length: 66, dtype: float64
# 66
# 281323.77274772915
# [4395.683949183268]
# 7
# 1
# this is: 9
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S010\S010R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      6723.546052
# Fc3.      3176.073062
# Fc1.      6872.316334
#              ...
# Po8.      6707.422316
# O1..      7466.312673
# Oz..      5175.557541
# O2..      5144.952223
# Iz..      3189.811659
# Length: 66, dtype: float64
# 66
# 329781.2418141342
# [5152.8319033458465]
# 7
# 1
# this is: 10
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S011\S011R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       746.347002
# Fc3.       514.450356
# Fc1.       509.547575
#              ...
# Po8.       864.119145
# O1..       862.342244
# Oz..       750.140180
# O2..       718.014410
# Iz..       376.572254
# Length: 66, dtype: float64
# 66
# 41356.300974785896
# [646.1922027310296]
# 7
# 1
# this is: 11
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S012\S012R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       334.547281
# Fc3.       430.375971
# Fc1.       428.559789
#              ...
# Po8.       424.911549
# O1..       481.441275
# Oz..       510.939247
# O2..       491.942566
# Iz..       441.762362
# Length: 66, dtype: float64
# 66
# 26229.49753936496
# [409.8358990525775]
# 7
# 1
# this is: 12
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S013\S013R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1351.999620
# Fc3.      1782.899886
# Fc1.      1956.347181
#              ...
# Po8.      2003.229188
# O1..      1931.391219
# Oz..      1953.297801
# O2..      1983.802229
# Iz..      1620.938016
# Length: 66, dtype: float64
# 66
# 108133.50977674991
# [1689.5860902617173]
# 7
# 1
# this is: 13
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S014\S014R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       975.355841
# Fc3.       960.333663
# Fc1.       974.884244
#              ...
# Po8.      1132.147489
# O1..      1064.905105
# Oz..       731.900998
# O2..       849.714792
# Iz..       619.019836
# Length: 66, dtype: float64
# 66
# 56030.809691009046
# [875.4814014220163]
# 7
# 1
# this is: 14
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S015\S015R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      2729.680997
# Fc3.      2490.086445
# Fc1.      2474.359049
#              ...
# Po8.      3901.139055
# O1..      2864.425476
# Oz..      2950.455357
# O2..      3120.280838
# Iz..      2117.776251
# Length: 66, dtype: float64
# 66
# 165665.06583565765
# [2588.5166536821507]
# 7
# 1
# this is: 15
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S016\S016R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       527.235917
# Fc3.       561.117484
# Fc1.       550.793294
#              ...
# Po8.       435.217289
# O1..       529.335674
# Oz..       484.088105
# O2..       492.871016
# Iz..       588.449058
# Length: 66, dtype: float64
# 66
# 32492.461136809383
# [507.6947052626466]
# 7
# 1
# this is: 16
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S017\S017R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.     11528.281514
# Fc3.      6561.597122
# Fc1.      4397.547841
#              ...
# Po8.      3138.314025
# O1..      3701.281144
# Oz..      3482.326933
# O2..      3532.192089
# Iz..      2882.952392
# Length: 66, dtype: float64
# 66
# 300439.93194487214
# [4694.373936638627]
# 7
# 1
# this is: 17
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S018\S018R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       497.314832
# Fc3.       476.304405
# Fc1.       464.035588
#              ...
# Po8.       360.784568
# O1..       428.847677
# Oz..       436.054336
# O2..       433.929696
# Iz..       498.803721
# Length: 66, dtype: float64
# 66
# 28223.716157364575
# [440.9955649588215]
# 7
# 1
# this is: 18
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S019\S019R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       864.704021
# Fc3.       909.053057
# Fc1.      1014.922167
#              ...
# Po8.       522.703719
# O1..       918.431855
# Oz..       779.629328
# O2..       665.222444
# Iz..      1059.620359
# Length: 66, dtype: float64
# 66
# 50672.50228915617
# [791.7578482680651]
# 7
# 1
# this is: 19
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S020\S020R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       636.375027
# Fc3.       676.471023
# Fc1.       765.820037
#              ...
# Po8.       619.142356
# O1..       553.495703
# Oz..       497.861332
# O2..       485.309507
# Iz..       405.156559
# Length: 66, dtype: float64
# 66
# 44963.111418094464
# [702.548615907726]
# 7
# 1
# this is: 20
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S021\S021R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       490.397447
# Fc3.       516.310378
# Fc1.       637.425767
#              ...
# Po8.       748.321160
# O1..       755.086424
# Oz..       600.429642
# O2..       611.771512
# Iz..       490.933597
# Length: 66, dtype: float64
# 66
# 69701.14545686412
# [1089.0803977635019]
# 7
# 1
# this is: 21
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S022\S022R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1694.536759
# Fc3.      1617.712517
# Fc1.      1788.542849
#              ...
# Po8.      1989.492795
# O1..      1492.279756
# Oz..      1326.794898
# O2..      1652.537917
# Iz..      1038.567074
# Length: 66, dtype: float64
# 66
# 110002.70531595875
# [1718.7922705618555]
# 7
# 1
# this is: 22
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S023\S023R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      4323.949508
# Fc3.      4745.067076
# Fc1.      4854.498221
#              ...
# Po8.      3895.730492
# O1..      4633.619586
# Oz..      4037.315538
# O2..      4258.128951
# Iz..      3050.881976
# Length: 66, dtype: float64
# 66
# 289905.80955884897
# [4529.778274357015]
# 7
# 1
# this is: 23
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S024\S024R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1278.464051
# Fc3.      1393.410261
# Fc1.      1565.432909
#              ...
# Po8.      1381.571913
# O1..      1400.489217
# Oz..      1344.326062
# O2..      1361.633060
# Iz..      1185.005321
# Length: 66, dtype: float64
# 66
# 87467.19319476136
# [1366.6748936681463]
# 7
# 1
# this is: 24
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S025\S025R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1003.511278
# Fc3.      1242.502030
# Fc1.      1369.661928
#              ...
# Po8.      1183.135341
# O1..      1099.277746
# Oz..       799.673119
# O2..       970.651872
# Iz..       765.602118
# Length: 66, dtype: float64
# 66
# 69493.00913618114
# [1085.8282677528302]
# 7
# 1
# this is: 25
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S026\S026R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       585.291681
# Fc3.       627.164791
# Fc1.       674.973211
#              ...
# Po8.       560.235762
# O1..       759.090137
# Oz..       649.121170
# O2..      1642.676767
# Iz..       643.875026
# Length: 66, dtype: float64
# 66
# 45071.780633204595
# [704.2465723938218]
# 7
# 1
# this is: 26
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S027\S027R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      4092.737665
# Fc3.      3274.163257
# Fc1.      2792.373382
#              ...
# Po8.      1954.439750
# O1..      3455.420613
# Oz..      3830.951445
# O2..      3731.046528
# Iz..      1633.086953
# Length: 66, dtype: float64
# 66
# 232537.77462039568
# [3633.4027284436825]
# 7
# 1
# this is: 27
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S028\S028R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      5291.162214
# Fc3.      4813.090625
# Fc1.      4988.130042
#              ...
# Po8.      3918.894269
# O1..      4860.308408
# Oz..      4168.579841
# O2..      4109.072342
# Iz..      3308.358224
# Length: 66, dtype: float64
# 66
# 311963.56924406276
# [4874.430769438481]
# 7
# 1
# this is: 28
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S029\S029R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1244.138578
# Fc3.      1492.659890
# Fc1.      1550.076630
#              ...
# Po8.      5334.583295
# O1..      3128.504747
# Oz..      3161.181023
# O2..      3718.864482
# Iz..      1591.033618
# Length: 66, dtype: float64
# 66
# 105729.09805360332
# [1652.0171570875518]
# 7
# 1
# this is: 29
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S030\S030R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1182.580614
# Fc3.      1430.960794
# Fc1.      1495.599724
#              ...
# Po8.      1211.102649
# O1..      1282.830948
# Oz..      1043.784738
# O2..      1190.797429
# Iz..       721.630187
# Length: 66, dtype: float64
# 66
# 84448.21912607172
# [1319.5034238448707]
# 7
# 1
# this is: 30
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S031\S031R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1947.226636
# Fc3.      2350.121009
# Fc1.      2518.693242
#              ...
# Po8.      1687.455805
# O1..      1968.519452
# Oz..      1676.397432
# O2..      1667.141538
# Iz..      1183.028104
# Length: 66, dtype: float64
# 66
# 124722.06176031749
# [1948.7822150049608]
# 7
# 1
# this is: 31
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S032\S032R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      6144.840005
# Fc3.      6751.987956
# Fc1.      6948.334071
#              ...
# Po8.      6974.841538
# O1..      3668.930411
# Oz..      4491.929615
# O2..      3611.522429
# Iz..      3492.222204
# Length: 66, dtype: float64
# 66
# 426269.63755307306
# [6660.4630867667665]
# 7
# 1
# this is: 32
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S033\S033R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       465.924941
# Fc3.       531.491360
# Fc1.       516.143307
#              ...
# Po8.       421.621295
# O1..       227.812778
# Oz..       200.315078
# O2..       299.723880
# Iz..       169.716982
# Length: 66, dtype: float64
# 66
# 44872.50322262106
# [701.1328628534541]
# 7
# 1
# this is: 33
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S034\S034R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1106.060564
# Fc3.      1101.142225
# Fc1.       884.106249
#              ...
# Po8.      1682.707967
# O1..      1449.496153
# Oz..      1349.609859
# O2..      1273.483043
# Iz..      1094.954302
# Length: 66, dtype: float64
# 66
# 69095.32531813385
# [1079.6144580958414]
# 7
# 1
# this is: 34
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S035\S035R02.edf...
# EDF file detected
# ...
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      2455.062102
# Fc3.      2609.071183
# Fc1.      2249.043738
#              ...
# Po8.      1978.914367
# O1..      2883.142940
# Oz..      2422.475375
# O2..      3256.959955
# Iz..      2292.500314
# Length: 66, dtype: float64
# 66
# 170008.07619318235
# [2656.3761905184742]
# 7
# 1
# this is: 99
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S100\S100R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.         9.949818
# Fc3.      1544.426902
# Fc1.      1613.218203
#              ...
# Po8.      1283.488276
# O1..      1549.773925
# Oz..      1350.748484
# O2..      1272.255098
# Iz..       744.185334
# Length: 66, dtype: float64
# 66
# 151281.59419915773
# [2363.7749093618395]
# 7
# 1
# this is: 100
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S101\S101R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      5490.584070
# Fc3.      3769.075079
# Fc1.      3402.147230
#              ...
# Po8.      1884.269624
# O1..      2366.460031
# Oz..      2156.564120
# O2..      2141.473817
# Iz..      1571.287603
# Length: 66, dtype: float64
# 66
# 243781.7225873263
# [3809.0894154269736]
# 7
# 1
# this is: 101
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S102\S102R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.       516.091507
# Fc3.       610.029392
# Fc1.       580.586361
#              ...
# Po8.       410.406746
# O1..       482.689616
# Oz..       428.500067
# O2..       396.998529
# Iz..       352.757211
# Length: 66, dtype: float64
# 66
# 36970.2244884963
# [577.6597576327547]
# 7
# 1
# this is: 102
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S103\S103R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.     13051.497432
# Fc3.     17642.057820
# Fc1.     16692.038253
#              ...
# Po8.     16670.867822
# O1..     16918.463648
# Oz..     19527.053003
# O2..     17711.485945
# Iz..     23693.478100
# Length: 66, dtype: float64
# 66
# 1079237.8666707973
# [16863.09166673121]
# 7
# 1
# this is: 103
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S104\S104R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      2132.306844
# Fc3.      2216.888268
# Fc1.      2113.453995
#              ...
# Po8.      3085.911138
# O1..      2463.092214
# Oz..      2368.979406
# O2..      2885.540461
# Iz..      1915.050876
# Length: 66, dtype: float64
# 66
# 153861.67517383635
# [2404.088674591193]
# 7
# 1
# this is: 104
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S105\S105R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.         1.480771
# Fc3.      1799.128219
# Fc1.         3.805841
#              ...
# Po8.      2322.195956
# O1..      2986.529270
# Oz..      2706.284612
# O2..      2711.673910
# Iz..      1483.055792
# Length: 66, dtype: float64
# 66
# 110270.29779606237
# [1722.9734030634745]
# 7
# 1
# this is: 105
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S106\S106R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      2996.232669
# Fc3.      3062.732944
# Fc1.      3955.850357
#              ...
# Po8.      4103.979880
# O1..      3384.614504
# Oz..      4378.715368
# O2..      3657.587072
# Iz..      1479.869109
# Length: 66, dtype: float64
# 66
# 218824.69081784578
# [3419.1357940288403]
# 7
# 1
# this is: 106
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S107\S107R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      4161.343380
# Fc3.      4247.968443
# Fc1.      4242.990269
#              ...
# Po8.      3770.632123
# O1..      5142.713951
# Oz..      5415.628540
# O2..      4720.629696
# Iz..      3240.324092
# Length: 66, dtype: float64
# 66
# 233001.298786276
# [3640.6452935355624]
# 7
# 1
# this is: 107
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S108\S108R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      2263.380295
# Fc3.      2225.783734
# Fc1.      2461.752526
#              ...
# Po8.      4871.440879
# O1..      5698.752915
# Oz..      4646.299866
# O2..      4580.649343
# Iz..      2288.601990
# Length: 66, dtype: float64
# 66
# 173002.68048685452
# [2703.166882607102]
# 7
# 1
# this is: 108
# Extracting EDF parameters from C:\Users\admin\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S109\S109R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0']
# Not setting metadata
# Not setting metadata
# 30 matching events found
# Setting baseline interval to [-0.2, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 30 events and 113 original time points ...
# 1 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# time     41567.238938
# epoch       70.000000
# Fc5.      1101.526166
# Fc3.      3795.406195
# Fc1.      8991.388615
#              ...
# Po8.      2376.878686
# O1..      3025.798268
# Oz..      4902.500635
# O2..      3659.479840
# Iz..      3887.070983
# Length: 66, dtype: float64
# 66
# 305581.87266558403
# [4774.7167603997505]
# 7
# 1
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7024/1599833014.py in <module>
#     145 #         ws.cell(row=i+2, column=2*len(result)+x+1).value = result[x][0]
#     146
# --> 147 wb.save('mne_data_analysis_fp2.xlsx')
#     148
#     149
#
# ~\anaconda3\envs\mne\lib\site-packages\openpyxl\workbook\workbook.py in save(self, filename)
#     405         if self.write_only and not self.worksheets:
#     406             self.create_sheet()
# --> 407         save_workbook(self, filename)
#     408
#     409
#
# ~\anaconda3\envs\mne\lib\site-packages\openpyxl\writer\excel.py in save_workbook(workbook, filename)
#     289
#     290     """
# --> 291     archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292     writer = ExcelWriter(workbook, archive)
#     293     writer.save()
#
# ~\anaconda3\envs\mne\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1237             while True:
#    1238                 try:
# -> 1239                     self.fp = io.open(file, filemode)
#    1240                 except OSError:
#    1241                     if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'mne_data_analysis_fp2.xlsx'

# %%
print(['Fc5.', 'Fc3.', 'Fc1.', 'Fcz.', 'Fc2.', 'Fc4.', 'Fc6.', 'C5..', 'C3..', 'C1..', 'Cz..', 'C2..', 'C4..', 'C6..', 'Cp5.', 'Cp3.', 'Cp1.', 'Cpz.', 'Cp2.', 'Cp4.', 'Cp6.', 'Fp1.', 'Fpz.', 'Fp2.', 'Af7.', 'Af3.', 'Afz.', 'Af4.', 'Af8.', 'F7..', 'F5..', 'F3..', 'F1..', 'Fz..', 'F2..', 'F4..', 'F6..', 'F8..', 'Ft7.', 'Ft8.', 'T7..', 'T8..', 'T9..', 'T10.', 'Tp7.', 'Tp8.', 'P7..', 'P5..', 'P3..', 'P1..', 'Pz..', 'P2..', 'P4..', 'P6..', 'P8..', 'Po7.', 'Po3.', 'Poz.', 'Po4.', 'Po8.', 'O1..', 'Oz..', 'O2..', 'Iz..'])

# %%
mne.datasets.brainstorm.bst_resting.data_path(path=None, force_update=False, update_path=True, download=True, accept=False, verbose=None)
